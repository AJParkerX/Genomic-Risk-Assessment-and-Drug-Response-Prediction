# %%
import pandas as pd
import gzip

# Path to the GWAS summary statistics file
file_path = 'neale_ukb_real_gwas_height.tsv.bgz'

# Read the compressed file
with gzip.open(file_path, 'rt') as f:
    gwas_df = pd.read_csv(f, sep='\t')

# Show first few rows
print(gwas_df.head())
# Out:
#          variant minor_allele      minor_AF  low_confidence_variant  \
# 0    1:15791:C:T            T  5.440760e-09                    True
# 1    1:69487:G:A            A  5.761760e-06                    True
# 2    1:69569:T:C            C  1.881580e-04                    True
# 3   1:139853:C:T            T  5.674710e-06                    True
# 4  1:692794:CA:C            C  1.106010e-01                   False
#
#    n_complete_samples            AC           ytx        beta           se  \
# 0              360388      0.003922  6.980390e-01  361.765000  1608.870000
# 1              360388      4.152940  7.002860e+02   -0.465050     3.151390
# 2              360388    135.620000  2.287850e+04   -0.434486     0.565187
# 3              360388      4.090200  6.895140e+02   -0.473593     3.151490
# 4              360388  79718.500000  1.345990e+07    0.005399     0.026135
#
#       tstat      pval
# 0  0.224856  0.822091
# 1 -0.147570  0.882682
# 2 -0.768747  0.442044
# ...

# %%
gwas_df.head()
# Out:
#          variant minor_allele      minor_AF  low_confidence_variant  \
# 0    1:15791:C:T            T  5.440760e-09                    True
# 1    1:69487:G:A            A  5.761760e-06                    True
# 2    1:69569:T:C            C  1.881580e-04                    True
# 3   1:139853:C:T            T  5.674710e-06                    True
# 4  1:692794:CA:C            C  1.106010e-01                   False
#
#    n_complete_samples            AC           ytx        beta           se  \
# 0              360388      0.003922  6.980390e-01  361.765000  1608.870000
# 1              360388      4.152940  7.002860e+02   -0.465050     3.151390
# 2              360388    135.620000  2.287850e+04   -0.434486     0.565187
# 3              360388      4.090200  6.895140e+02   -0.473593     3.151490
# 4              360388  79718.500000  1.345990e+07    0.005399     0.026135
#
#       tstat      pval
# 0  0.224856  0.822091
# 1 -0.147570  0.882682
# 2 -0.768747  0.442044
# ...

# %%
gwas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13791467 entries, 0 to 13791466
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   variant                 object
#  1   minor_allele            object
#  2   minor_AF                float64
#  3   low_confidence_variant  bool
#  4   n_complete_samples      int64
#  5   AC                      float64
#  6   ytx                     float64
#  7   beta                    float64
#  8   se                      float64
#  9   tstat                   float64
#  10  pval                    float64
# dtypes: bool(1), float64(7), int64(1), object(2)
# memory usage: 1.0+ GB
