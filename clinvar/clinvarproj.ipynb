# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Load in chunks if too large
chunks = pd.read_csv("variant_summary.txt", sep="\t", chunksize=50000, low_memory=False)

# %%
import pandas as pd

# Show all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)  # Be careful if data is huge

# %%
# Get the first chunk and display its info
first_chunk = next(chunks)
first_chunk.head()
# Out:
#         #AlleleID                       Type  \
# 300000     240773  single nucleotide variant
# 300001     240774  single nucleotide variant
# 300002     240774  single nucleotide variant
# 300003     240775  single nucleotide variant
# 300004     240775  single nucleotide variant
#
#                                               Name  GeneID GeneSymbol  \
# 300000  NM_018076.5(ODAD2):c.1922T>C (p.Leu641Pro)   55130      ODAD2
# 300001    NM_018076.5(ODAD2):c.1353T>C (p.Tyr451=)   55130      ODAD2
# 300002    NM_018076.5(ODAD2):c.1353T>C (p.Tyr451=)   55130      ODAD2
# 300003    NM_018076.5(ODAD2):c.1272C>T (p.Ser424=)   55130      ODAD2
# 300004    NM_018076.5(ODAD2):c.1272C>T (p.Ser424=)   55130      ODAD2
#
#            HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 300000  HGNC:25583  Uncertain significance              0  Nov 09, 2023
# 300001  HGNC:25583           Likely benign              0  Jan 20, 2025
# ...

# %%
first_chunk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 300000 to 349999
# Data columns (total 43 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   #AlleleID                                   50000 non-null  int64
#  1   Type                                        50000 non-null  object
#  2   Name                                        50000 non-null  object
#  3   GeneID                                      50000 non-null  int64
#  4   GeneSymbol                                  50000 non-null  object
#  5   HGNC_ID                                     50000 non-null  object
#  6   ClinicalSignificance                        50000 non-null  object
#  7   ClinSigSimple                               50000 non-null  int64
#  8   LastEvaluated                               50000 non-null  object
# ...

# %%
matching_rows = first_chunk[first_chunk['GeneSymbol'] == 'A2ML1']
matching_rows.head()
# Out:
#         #AlleleID                       Type  \
# 301612     241583  single nucleotide variant
# 301613     241583  single nucleotide variant
# 301614     241584  single nucleotide variant
# 301615     241584  single nucleotide variant
# 301616     241585  single nucleotide variant
#
#                                             Name  GeneID GeneSymbol  \
# 301612       NM_144670.6(A2ML1):c.9T>A (p.Ala3=)  144568      A2ML1
# 301613       NM_144670.6(A2ML1):c.9T>A (p.Ala3=)  144568      A2ML1
# 301614  NM_144670.6(A2ML1):c.200A>T (p.Glu67Val)  144568      A2ML1
# 301615  NM_144670.6(A2ML1):c.200A>T (p.Glu67Val)  144568      A2ML1
# 301616             NM_144670.6(A2ML1):c.483+7G>A  144568      A2ML1
#
#            HGNC_ID  ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 301612  HGNC:23336  Benign/Likely benign              0  Jan 31, 2025
# 301613  HGNC:23336  Benign/Likely benign              0  Jan 31, 2025
# ...
